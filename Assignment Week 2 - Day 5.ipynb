# %% [markdown]
# # **SQL**

# %%
# !pip install pymysql
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.pool import NullPool
def mysql(query:'Write the query here .'):
    '''
    This function fetches data from database and returns the result.
    '''
    try:
        engine_db = create_engine('mysql+pymysql://almafolk:8l39zk60q@learning-activity.cejogcrmn6il.ap-south-1.rds.amazonaws.com:3306/assignment', poolclass=NullPool )
        conn = engine_db.connect()
        # Reading Data
        df = pd.read_sql_query(query, conn)

        #if your connection object is named conn
        if not conn.closed:
            conn.close()
        engine_db.dispose()
        return df
    except Exception as e:
        print(e)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 43 kB 2.0 MB/s
# ...

# %% [markdown]
# **Introduction**

# %% [markdown]
# Did you know that over 115 million kilograms of pizza is consumed daily worldwide??? (Well according to Wikipedia anyway…)
#
# Danny was scrolling through his Instagram feed when something really caught his eye - “80s Retro Styling and Pizza Is The Future!”
#
# Danny was sold on the idea, but he knew that pizza alone was not going to help him get seed funding to expand his new Pizza Empire - so he had one more genius idea to combine with it - he was going to Uberize it - and so Pizza Runner was launched!
#
# Danny started by recruiting “runners” to deliver fresh pizza from Pizza Runner Headquarters (otherwise known as Danny’s house) and also maxed out his credit card to pay freelance developers to build a mobile app to accept orders from customers.

# %% [markdown]
# **Available Data**

# %% [markdown]
# Because Danny had a few years of experience as a data scientist - he was very aware that data collection was going to be critical for his business’ growth.
#
# He has prepared for us an entity relationship diagram of his database design but requires further assistance to clean his data and apply some basic calculations so he can better direct his runners and optimise Pizza Runner’s operations.
#
# All datasets exist within the pizza_runner database schema - be sure to include this reference within your SQL scripts as you start exploring the data and answering the case study questions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Table 1: runners**
#
# The runners table shows the registration_date for each new runner

# %% [markdown]
# **Table 2: customer_orders**
#
# Customer pizza orders are captured in the customer_orders table with 1 row for each individual pizza that is part of the order.
#
# The pizza_id relates to the type of pizza which was ordered whilst the exclusions are the ingredient_id values which should be removed from the pizza and the extras are the ingredient_id values which need to be added to the pizza.
#
# Note that customers can order multiple pizzas in a single order with varying exclusions and extras values even if the pizza is the same type!
#
# The exclusions and extras columns will need to be cleaned up before using them in your queries.

# %% [markdown]
# **Table 3: runner_orders**
#
# After each orders are received through the system - they are assigned to a runner - however not all orders are fully completed and can be cancelled by the restaurant or the customer.
#
# The pickup_time is the timestamp at which the runner arrives at the Pizza Runner headquarters to pick up the freshly cooked pizzas. The distance and duration fields are related to how far and long the runner had to travel to deliver the order to the respective customer.
#
# There are some known data issues with this table so be careful when using this in your queries - make sure to check the data types for each column in the schema SQL!

# %% [markdown]
# **Table 4: pizza_names**
#
# At the moment - Pizza Runner only has 2 pizzas available the Meat Lovers or Vegetarian!

# %% [markdown]
# **Table 5: pizza_recipes**
#
# Each pizza_id has a standard set of toppings which are used as part of the pizza recipe.

# %% [markdown]
# **Table 6: pizza_toppings**
#
# This table contains all of the topping_name values with their corresponding topping_id value

# %% [markdown]
# **Case Study Questions**

# %% [markdown]
# ## 1. a How many pizzas were ordered?
#
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
mysql('select count(distinct customer_orders.order_id,customer_orders.pizza_id) as no_of_pizzas_ordered   from runner_orders left join customer_orders on runner_orders.order_id=customer_orders.order_id where runner_orders.pickup_time != "null" ')
# Out:
#    no_of_pizzas_ordered
# 0                    10

# %% [markdown]
# ## 1. b. How many unique customer orders were made?
#
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Write Your code here.
mysql('select customer_orders.customer_id, count(pizza_id) as unique_orders from runner_orders left join customer_orders on runner_orders.order_id=customer_orders.order_id group by customer_orders.customer_id')
# Out:
#    customer_id  unique_orders
# 0          101              3
# 1          102              3
# 2          103              4
# 3          104              3
# 4          105              1

# %% [markdown]
# ## 2. a. How many successful orders were delivered by each runner?
#
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Write Your code here.
mysql('select count(distinct runner_orders.runner_id,runner_orders.pickup_time) as successful_orderes  from runner_orders left join customer_orders on runner_orders.order_id=customer_orders.order_id where runner_orders.pickup_time != "null" ')
# Out:
#    successful_orderes
# 0                   8

# %% [markdown]
# ## 2. b. How many of each type of pizza was delivered?
#
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Write Your code here.
mysql('select count(customer_orders.pizza_id) as no_of_delivered_pizza  from runner_orders left join customer_orders on runner_orders.order_id=customer_orders.order_id where runner_orders.pickup_time != "null" group by  customer_orders.pizza_id')
# Out:
#    no_of_delivered_pizza
# 0                      9
# 1                      3

# %%
# !pip install pymysql
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.pool import NullPool
def mysql(query:'Write the query here .'):
    '''
    This function fetches data from database and returns the result.
    '''
    try:
        engine_db = create_engine('mysql+pymysql://almafolk:8l39zk60q@learning-activity.cejogcrmn6il.ap-south-1.rds.amazonaws.com:3306/assignment', poolclass=NullPool )
        conn = engine_db.connect()
        # Reading Data
        df = pd.read_sql_query(query, conn)

        #if your connection object is named conn
        if not conn.closed:
            conn.close()
        engine_db.dispose()
        return df
    except Exception as e:
        print(e)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Introduction**

# %% [markdown]
# Did you know that over 115 million kilograms of pizza is consumed daily worldwide??? (Well according to Wikipedia anyway…)
#
# Danny was scrolling through his Instagram feed when something really caught his eye - “80s Retro Styling and Pizza Is The Future!”
#
# Danny was sold on the idea, but he knew that pizza alone was not going to help him get seed funding to expand his new Pizza Empire - so he had one more genius idea to combine with it - he was going to Uberize it - and so Pizza Runner was launched!
#
# Danny started by recruiting “runners” to deliver fresh pizza from Pizza Runner Headquarters (otherwise known as Danny’s house) and also maxed out his credit card to pay freelance developers to build a mobile app to accept orders from customers.

# %% [markdown]
# **Available Data**

# %% [markdown]
# Because Danny had a few years of experience as a data scientist - he was very aware that data collection was going to be critical for his business’ growth.
#
# He has prepared for us an entity relationship diagram of his database design but requires further assistance to clean his data and apply some basic calculations so he can better direct his runners and optimise Pizza Runner’s operations.
#
# All datasets exist within the pizza_runner database schema - be sure to include this reference within your SQL scripts as you start exploring the data and answering the case study questions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Table 1: runners**
#
# The runners table shows the registration_date for each new runner

# %% [markdown]
# **Table 2: customer_orders**
#
# Customer pizza orders are captured in the customer_orders table with 1 row for each individual pizza that is part of the order.
#
# The pizza_id relates to the type of pizza which was ordered whilst the exclusions are the ingredient_id values which should be removed from the pizza and the extras are the ingredient_id values which need to be added to the pizza.
#
# Note that customers can order multiple pizzas in a single order with varying exclusions and extras values even if the pizza is the same type!
#
# The exclusions and extras columns will need to be cleaned up before using them in your queries.

# %% [markdown]
# **Table 3: runner_orders**
#
# After each orders are received through the system - they are assigned to a runner - however not all orders are fully completed and can be cancelled by the restaurant or the customer.
#
# The pickup_time is the timestamp at which the runner arrives at the Pizza Runner headquarters to pick up the freshly cooked pizzas. The distance and duration fields are related to how far and long the runner had to travel to deliver the order to the respective customer.
#
# There are some known data issues with this table so be careful when using this in your queries - make sure to check the data types for each column in the schema SQL!

# %% [markdown]
# **Table 4: pizza_names**
#
# At the moment - Pizza Runner only has 2 pizzas available the Meat Lovers or Vegetarian!

# %% [markdown]
# **Table 5: pizza_recipes**
#
# Each pizza_id has a standard set of toppings which are used as part of the pizza recipe.

# %% [markdown]
# **Table 6: pizza_toppings**
#
# This table contains all of the topping_name values with their corresponding topping_id value

# %% [markdown]
# **Case Study Questions**

# %% [markdown]
# ## 3. How many Vegetarian and Meatlovers were ordered by each customer?
#
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Write Your code here.
mysql('select customer_orders.customer_id,pizza_names.pizza_name, count(pizza_names.pizza_name) as no_of_orders from runner_orders left join customer_orders on runner_orders.order_id=customer_orders.order_id left join pizza_names on customer_orders.pizza_id=pizza_names.pizza_id  group by customer_orders.customer_id,pizza_names.pizza_name order by customer_orders.customer_id  ')
# Out:
#    customer_id  pizza_name  no_of_orders
# 0          101  Meatlovers             2
# 1          101  Vegetarian             1
# 2          102  Meatlovers             2
# 3          102  Vegetarian             1
# 4          103  Meatlovers             3
# 5          103  Vegetarian             1
# 6          104  Meatlovers             3
# 7          105  Vegetarian             1

# %% [markdown]
# ## 4. What was the maximum number of pizzas delivered in a single order?
#
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Write Your code here.
mysql('select  count(pizza_names.pizza_name) as max_no_pizzas_in_single_order from runner_orders left join customer_orders on runner_orders.order_id=customer_orders.order_id left join pizza_names on customer_orders.pizza_id=pizza_names.pizza_id  group by customer_orders.customer_id,pizza_names.pizza_name order by max_no_pizzas_in_single_order desc limit 1  ')
# Out:
#    max_no_pizzas_in_single_order
# 0                              3

# %% [markdown]
# # **MATH**

# %% [markdown]
# ## 5&6. Let X and Y be two jointly continuous random variables with joint PDF
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Upload Your answer here.
# ![IMG_20220919_191549.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![IMG_20220919_191559.jpg](data:image/jpeg;base64,...)
